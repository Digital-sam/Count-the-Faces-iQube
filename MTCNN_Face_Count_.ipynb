# %% [markdown]
# # Count The Faces
#
# A computer vison(CV) model is a processing block that takes uploded inputs, like images or videos and predicts or returns pre-learned concepts or lebels. CV models can be trained to see almost anything humans can see. The general model CV can recognize concepts and give it a meaning.
#
# #### There are various approches to solving a CV problem namely:
# <ul>
#     <li>Building a model from scratch</li>
#     <li>The use of pretrained model and fine tune for the desired purpose</li>
# </ul>
#
# In this project, the approach to solving this problem is to use a Multi-task Cascaded Convolutional Neural Network(MTCNN)  which is a neural network that detects faces and facial landmarks on images. It was published by Zhang et al "Joint Face detection and alignment using multitask Cascaded Convolutional Network" in 2016. The major advantage of using the MTCNN is the ability to run well and with great accuracy on CPU. The MTCNN is one of the most popular and most accurate face detection tools today.

# %%
# Loading required libraries
from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN 
import tensorflow as tf
import tensorflow.keras as Keras
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
#Create a directory

filename = 'C:/Users/LENOVO/Desktop/iQube/test_'

# %%
#loading sample image
dir = filename + '/' + "tri.jpg"           # loading image
image = Image.open(dir)                    #loading image from given path
image = image.convert('RGB')               # converting image into 3D (RGB) image
pixels = asarray(image)

plt.imshow(pixels)
plt.axis('off')
pixels.shape
# Out:
# (394, 820, 3)

# %%
#extraction using MTCNN
detector = MTCNN()     
results = detector.detect_faces(pixels)

total_faces = len(results)

for face in range(total_faces):
  print('box : {}'.format(results[face]['box']))
  print('confidence : {}'.format(results[face]['confidence']))
  print('keypoints : {}'.format(results[face]['keypoints']))
# Out:
# box : [197, 82, 84, 141]
# confidence : 0.9999971389770508
# keypoints : {'left_eye': (256, 142), 'right_eye': (278, 149), 'nose': (275, 181), 'mouth_left': (235, 196), 'mouth_right': (256, 200)}
# box : [464, 49, 103, 137]
# confidence : 0.9898119568824768
# keypoints : {'left_eye': (489, 103), 'right_eye': (536, 95), 'nose': (514, 118), 'mouth_left': (500, 156), 'mouth_right': (542, 149)}

# %%
# Use the MTCNN model to count the number of faces

output = []

# diretory of image
dir = filename + '/' + "truu.jpg"
image = Image.open(dir)            #loading image from given path
image = image.convert('RGB')       # converting image into 3D (RGB) image
pixels = asarray(image)            


# face extraction
detector = MTCNN()                 
results = detector.detect_faces(pixels)

# len(results) returns number of faces in an image
output.append(len(results))
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A38652C7B8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
#show the image and the prediction
plt.imshow(pixels)
print('number of people in the picture is : {}'.format(output))
# Out:
# number of people in the picture is : [5]

# %%
output = []

# diretory of image
dir = filename + '/' + "true.jpg"
image = Image.open(dir)            #loading image from given path
image = image.convert('RGB')       # converting image into 3D (RGB) image
pixels = asarray(image)            


# face extraction
detector = MTCNN()                 
results = detector.detect_faces(pixels)

# len(results) returns number of faces in an image
output.append(len(results))
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A384C1C598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
#show the image and the prediction
plt.imshow(pixels)
print('number of people in the picture is : {}'.format(output))
# Out:
# number of people in the picture is : [3]

# %%
output = []

# diretory of image
dir = filename + '/' + "tri.jpg"
image = Image.open(dir)            #loading image from given path
image = image.convert('RGB')       # converting image into 3D (RGB) image
pixels = asarray(image)            


# face extraction
detector = MTCNN()                 
results = detector.detect_faces(pixels)

# len(results) returns number of faces in an image
output.append(len(results))
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A384DD6598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
#show the image and the prediction
plt.imshow(pixels)
print('number of people in the picture is : {}'.format(output))
# Out:
# number of people in the picture is : [2]
